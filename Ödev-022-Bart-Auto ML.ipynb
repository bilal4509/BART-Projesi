# %%
pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 95.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 86.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 21.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 70.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
#Regression AutoMl

# %%
from pycaret.regression import*

# %%
df=pd.read_csv("date-hour-soo-dest-2020.csv",names=['Date','Hour','Origin Station','Destination Station','Trip Count'])

# %%
df.head()
# Out:
#          Date  Hour Origin Station Destination Station  Trip Count
# 0  2020-01-01     0           12TH                16TH         5.0
# 1  2020-01-01     0           12TH                24TH         3.0
# 2  2020-01-01     0           12TH                ASHB         6.0
# 3  2020-01-01     0           12TH                BAYF         1.0
# 4  2020-01-01     0           12TH                CIVC         3.0

# %%
df.isnull().sum()
# Out:
# Date                   0
# Hour                   0
# Origin Station         0
# Destination Station    0
# Trip Count             1
# dtype: int64

# %%
df["Trip Count"]=df["Trip Count"].fillna(df["Trip Count"].mean())

# %%
df.isnull().sum()
# Out:
# Date                   0
# Hour                   0
# Origin Station         0
# Destination Station    0
# Trip Count             0
# dtype: int64

# %%
setup(data=df,target='Trip Count')
# Out:
# <style type="text/css">
# #T_35151_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_35151" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35151_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_35151_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35151_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35151_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_35151_row0_col1" class="data row0 col1" >3816</td>
#     </tr>
#     <tr>
#       <th id="T_35151_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35151_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_35151_row1_col1" class="data row1 col1" >Trip Count</td>
#     </tr>
#     <tr>
#       <th id="T_35151_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_92e56 th {
#   text-align: left;
# }
# ...
